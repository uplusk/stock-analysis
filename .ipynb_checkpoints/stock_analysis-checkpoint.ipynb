# %% [markdown]
# # Import necessary libraries

# %%
import quandl

import pandas as pd

import numpy as np

from fbprophet import Prophet

# matplotlib pyplot for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
 
plt.rcParams['figure.figsize']=(20,10)
plt.style.use('ggplot')

# stocker library
from stocker import Stocker

# set api key
quandl.ApiConfig.api_key = "sY8rR9LTz4kT5z2cs94v"

# %% [markdown]
# # Read in the data
# Read the data in from the quandl api for python and then set the index to the 'date' column. We are also parsing dates in the data file.

# %%
# L&T Finance Holdings data
stock_ltfh_df = quandl.get('NSE/LTFH')
stock_ltfh_df = stock_ltfh_df.reset_index(level=0)

# Motherson Sumi Data
stock_mothersumi_df = quandl.get('NSE/MOTHERSUMI')
stock_mothersumi_df = stock_mothersumi_df.reset_index(level=0)

# Anantraj Ltd. Data
stock_anantraj_df = quandl.get('NSE/ANANTRAJ')
stock_anantraj_df = stock_anantraj_df.reset_index(level=0)

# %%
stock_ltfh_df.tail()
# Out:
#            Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 1602 2018-01-31  175.00  177.65  170.50  172.40  172.60             5245741.0
# 1603 2018-02-01  173.15  175.50  168.35  171.70  171.05             4187437.0
# 1604 2018-02-02  169.60  169.80  154.85  156.75  157.70             9112430.0
# 1605 2018-02-05  151.55  159.80  144.35  159.60  158.40             9835428.0
# 1606 2018-02-06  149.00  161.65  147.55  159.60  159.35            11701257.0
#
#       Turnover (Lacs)
# 1602          9113.58
# 1603          7243.73
# 1604         14686.39
# 1605         15192.04
# 1606         18201.59

# %% [markdown]
# # Prepare for Prophet
# For prophet to work, we need to change the names of these columns to 'ds' and 'y', so lets just create a new dataframe and keep our old one handy. The new dataframe will initially be created with an integer index so we can rename the columns

# %%
stock_ltfh_df = stock_ltfh_df.rename(columns={'Date':'ds', 'Close':'y'})

stock_mothersumi_df = stock_mothersumi_df.rename(columns={'Date':'ds', 'Close':'y'})

stock_anantraj_df = stock_anantraj_df.rename(columns={'Date':'ds', 'Close':'y'})

# verifying just to make sure
stock_ltfh_df.tail()
# Out:
#              ds    Open    High     Low    Last       y  Total Trade Quantity  \
# 1602 2018-01-31  175.00  177.65  170.50  172.40  172.60             5245741.0
# 1603 2018-02-01  173.15  175.50  168.35  171.70  171.05             4187437.0
# 1604 2018-02-02  169.60  169.80  154.85  156.75  157.70             9112430.0
# 1605 2018-02-05  151.55  159.80  144.35  159.60  158.40             9835428.0
# 1606 2018-02-06  149.00  161.65  147.55  159.60  159.35            11701257.0
#
#       Turnover (Lacs)
# 1602          9113.58
# 1603          7243.73
# 1604         14686.39
# 1605         15192.04
# 1606         18201.59

# %% [markdown]
# Now's a good time to take a look at our data. Plotting the data using pandas' plot function

# %%
stock_ltfh_df.set_index('ds').y.plot()

# %% [markdown]
# Facebook prophet's example uses the log-transform as a way to remove some of these anomolies but it isn't the absolute 'best' way to do this...but given that its the example and a simple data series, We follow their lead for now. Taking the log of a number is easily reversible to be able to see your original data.
#
# To log-transform your data, you can use numpy's log() function

# %%
stock_ltfh_df['y_orig'] = stock_ltfh_df['y']

# %%
stock_ltfh_df['y'] = np.log(stock_ltfh_df['y'])

# %%
stock_ltfh_df.tail()
# Out:
#              ds    Open    High     Low    Last         y  \
# 1602 2018-01-31  175.00  177.65  170.50  172.40  5.150977
# 1603 2018-02-01  173.15  175.50  168.35  171.70  5.141956
# 1604 2018-02-02  169.60  169.80  154.85  156.75  5.060694
# 1605 2018-02-05  151.55  159.80  144.35  159.60  5.065123
# 1606 2018-02-06  149.00  161.65  147.55  159.60  5.071103
#
#       Total Trade Quantity  Turnover (Lacs)  y_orig
# 1602             5245741.0          9113.58  172.60
# 1603             4187437.0          7243.73  171.05
# 1604             9112430.0         14686.39  157.70
# 1605             9835428.0         15192.04  158.40
# 1606            11701257.0         18201.59  159.35

# %%
stock_ltfh_df.set_index('ds').y.plot()

# %% [markdown]
# # Running Prophet
# Now, let's set prophet up to begin modeling our data.
#
# Note: Since we are using daily data, you'll see a message from Prophet saying Disabling daily seasonality. Run prophet with daily_seasonality=True to override this. This is OK since we are working with daily data but you can disable it by using daily_seasonality=True in the instantiation of Prophet.

# %%
model = Prophet()

model.fit(stock_ltfh_df)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# Forecasting is fairly useless unless you can look into the future, so we need to add some future dates to our dataframe. For this example, I want to forecast 2 months into the future, so I'll built a future dataframe with 60 periods since we are working with daily data.
#
# This can be done with the following code:

# %%
future_data = model.make_future_dataframe(periods = 60)

# %%
forecast_data = model.predict(future_data)
forecast_data.tail()
# Out:
#              ds     trend  trend_lower  trend_upper  yhat_lower  yhat_upper  \
# 1662 2018-04-03  5.468409     5.433885     5.496116    5.324418    5.511879
# 1663 2018-04-04  5.470182     5.434663     5.497877    5.318855    5.511117
# 1664 2018-04-05  5.471956     5.434187     5.500909    5.316166    5.520207
# 1665 2018-04-06  5.473729     5.434638     5.503291    5.321897    5.519504
# 1666 2018-04-07  5.475503     5.435996     5.506652    5.322253    5.514466
#
#       seasonal  seasonal_lower  seasonal_upper  seasonalities  \
# 1662 -0.051725       -0.051725       -0.051725      -0.051725
# 1663 -0.050898       -0.050898       -0.050898      -0.050898
# 1664 -0.051441       -0.051441       -0.051441      -0.051441
# 1665 -0.051479       -0.051479       -0.051479      -0.051479
# 1666 -0.053896       -0.053896       -0.053896      -0.053896
#
#       seasonalities_lower  seasonalities_upper    weekly  weekly_lower  \
# 1662            -0.051725            -0.051725 -0.011179     -0.011179
# 1663            -0.050898            -0.050898 -0.010812     -0.010812
# 1664            -0.051441            -0.051441 -0.011896     -0.011896
# 1665            -0.051479            -0.051479 -0.012545     -0.012545
# 1666            -0.053896            -0.053896 -0.015637     -0.015637
#
#       weekly_upper    yearly  yearly_lower  yearly_upper      yhat
# 1662     -0.011179 -0.040546     -0.040546     -0.040546  5.416683
# 1663     -0.010812 -0.040086     -0.040086     -0.040086  5.419284
# 1664     -0.011896 -0.039546     -0.039546     -0.039546  5.420514
# 1665     -0.012545 -0.038933     -0.038933     -0.038933  5.422250
# 1666     -0.015637 -0.038259     -0.038259     -0.038259  5.421607

# %% [markdown]
# We really only want to look at yhat, yhat_lower and yhat_upper, here yhat is the forecasted value, yhat_upper and yhat_lower are the uncertainity levels(upper and lower bounds) respectively, so we can do that with:

# %%
forecast_data[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 1662 2018-04-03  5.416683    5.324418    5.511879
# 1663 2018-04-04  5.419284    5.318855    5.511117
# 1664 2018-04-05  5.420514    5.316166    5.520207
# 1665 2018-04-06  5.422250    5.321897    5.519504
# 1666 2018-04-07  5.421607    5.322253    5.514466

# %% [markdown]
# # Plotting Prophet results
# Prophet has a plotting mechanism called plot. This plot functionality draws the original data (black dots), the model (blue line) and the error of the forecast (shaded blue area).

# %%
model.plot(forecast_data);

# %% [markdown]
# # Visualizing Prophet models
# In order to build a useful dataframe to visualize our model versus our original data, we need to combine the output of the Prophet model with our original data set, then we'll build a new chart manually using pandas and matplotlib.
#
# First, let's set our dataframes to have the same index of ds

# %%
stock_ltfh_df.set_index('ds', inplace=True)
forecast_data.set_index('ds', inplace=True)

# %% [markdown]
# Now, we'll combine the original data and our forecast model data

# %%
combined_df = stock_ltfh_df.join(forecast_data[['yhat', 'yhat_lower','yhat_upper']], how = 'outer')

# %%
combined_df.tail()
# Out:
#             Open  High  Low  Last   y  Total Trade Quantity  Turnover (Lacs)  \
# ds
# 2018-04-03   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04-04   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04-05   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04-06   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04-07   NaN   NaN  NaN   NaN NaN                   NaN              NaN
#
#             y_orig      yhat  yhat_lower  yhat_upper
# ds
# 2018-04-03     NaN  5.416683    5.324418    5.511879
# 2018-04-04     NaN  5.419284    5.318855    5.511117
# 2018-04-05     NaN  5.420514    5.316166    5.520207
# 2018-04-06     NaN  5.422250    5.321897    5.519504
# 2018-04-07     NaN  5.421607    5.322253    5.514466

# %%
combined_df['yhat_rescaled'] = np.exp(combined_df['yhat'])

# %%
combined_df.head()
# Out:
#              Open   High    Low   Last         y  Total Trade Quantity  \
# ds
# 2011-08-12  53.85  53.85  49.30  49.95  3.913023            98188151.0
# 2011-08-16  50.90  51.30  49.00  49.20  3.897924            12435359.0
# 2011-08-17  49.65  49.80  48.00  48.10  3.874321             4804559.0
# 2011-08-18  48.15  48.50  46.15  46.20  3.835142             4346287.0
# 2011-08-19  46.05  46.05  44.65  44.95  3.804438             4196723.0
#
#             Turnover (Lacs)  y_orig      yhat  yhat_lower  yhat_upper  \
# ds
# 2011-08-12         49996.43   50.05  3.871420    3.788447    3.958227
# 2011-08-16          6228.64   49.30  3.868424    3.774317    3.960862
# 2011-08-17          2338.70   48.15  3.868123    3.781498    3.952963
# 2011-08-18          2041.48   46.30  3.866603    3.784355    3.955921
# 2011-08-19          1889.71   44.90  3.865775    3.776360    3.950466
#
#             yhat_rescaled
# ds
# 2011-08-12      48.010493
# 2011-08-16      47.866868
# 2011-08-17      47.852494
# 2011-08-18      47.779819
# 2011-08-19      47.740253

# %% [markdown]
# Let's take a look at the original prices and yhat_rescaled data(the predicted prices) together in a chart.

# %%
combined_df[['y_orig','yhat_rescaled']].plot()

# %% [markdown]
# You can see from the chart that the model (blue) is pretty good when plotted against the actual signal (orange). To make it even better, we'll need to go back to our original stock_ltfh_df and forecast_data dataframes.
#
# First things first - we need to find the 2nd to last date of the original prices data in stock_ltfh_df in order to ensure the original prices data and model data charts are connected.

# %%
stock_ltfh_df.index = pd.to_datetime(stock_ltfh_df.index) #make sure our index as a datetime object
connect_date = stock_ltfh_df.index[-2] #select the 2nd to last date

# %% [markdown]
# Using the connect_date we can now grab only the model data that after that date. To do this, we'll mask the forecast data.

# %%
mask = (forecast_data.index > connect_date)
prediction_df = forecast_data.loc[mask]

# %%
prediction_df.tail()
# Out:
#                trend  trend_lower  trend_upper  yhat_lower  yhat_upper  \
# ds
# 2018-04-03  5.468409     5.433885     5.496116    5.324418    5.511879
# 2018-04-04  5.470182     5.434663     5.497877    5.318855    5.511117
# 2018-04-05  5.471956     5.434187     5.500909    5.316166    5.520207
# 2018-04-06  5.473729     5.434638     5.503291    5.321897    5.519504
# 2018-04-07  5.475503     5.435996     5.506652    5.322253    5.514466
#
#             seasonal  seasonal_lower  seasonal_upper  seasonalities  \
# ds
# 2018-04-03 -0.051725       -0.051725       -0.051725      -0.051725
# 2018-04-04 -0.050898       -0.050898       -0.050898      -0.050898
# 2018-04-05 -0.051441       -0.051441       -0.051441      -0.051441
# 2018-04-06 -0.051479       -0.051479       -0.051479      -0.051479
# 2018-04-07 -0.053896       -0.053896       -0.053896      -0.053896
#
#             seasonalities_lower  seasonalities_upper    weekly  weekly_lower  \
# ds
# 2018-04-03            -0.051725            -0.051725 -0.011179     -0.011179
# 2018-04-04            -0.050898            -0.050898 -0.010812     -0.010812
# 2018-04-05            -0.051441            -0.051441 -0.011896     -0.011896
# 2018-04-06            -0.051479            -0.051479 -0.012545     -0.012545
# 2018-04-07            -0.053896            -0.053896 -0.015637     -0.015637
#
#             weekly_upper    yearly  yearly_lower  yearly_upper      yhat
# ds
# 2018-04-03     -0.011179 -0.040546     -0.040546     -0.040546  5.416683
# 2018-04-04     -0.010812 -0.040086     -0.040086     -0.040086  5.419284
# 2018-04-05     -0.011896 -0.039546     -0.039546     -0.039546  5.420514
# 2018-04-06     -0.012545 -0.038933     -0.038933     -0.038933  5.422250
# 2018-04-07     -0.015637 -0.038259     -0.038259     -0.038259  5.421607

# %% [markdown]
# Now, let's build a dataframe to use in our new visualization. We'll follow the same steps we did before.

# %%
combined_df = stock_ltfh_df.join(prediction_df[['yhat', 'yhat_lower','yhat_upper']], how = 'outer')

# %%
combined_df['yhat_rescaled'] = np.exp(combined_df['yhat'])

# %% [markdown]
# # Time to plot
# Now, let's plot everything to get the 'final' visualization of our stock price data and forecast with errors.

# %%
fig, ax1 = plt.subplots()
ax1.plot(combined_df.y_orig)
ax1.plot(combined_df.yhat_rescaled, color='black', linestyle=':')
ax1.fill_between(combined_df.index, np.exp(combined_df['yhat_upper']), np.exp(combined_df['yhat_lower']), alpha=0.5, color='darkgray')
ax1.set_title('Stock Price(Orange) vs Stock Price Forecast (Black)')
ax1.set_ylabel('Stock Prices (INR)')
ax1.set_xlabel('Date')

L=ax1.legend() #get the legend
L.get_texts()[0].set_text('Actual Price') #change the legend text for 1st plot
L.get_texts()[1].set_text('Forecasted Price') #change the legend text for 2nd plot

# %%
combined_df.tail(50)
# Out:
#             Open  High  Low  Last   y  Total Trade Quantity  Turnover (Lacs)  \
# ds
# 2018-02-17   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-18   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-19   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-20   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-21   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-22   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-23   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-24   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-25   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-26   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-27   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-02-28   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-01   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-02   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-03   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-04   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-05   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-06   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-07   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-08   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-09   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-10   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-11   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-12   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-13   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-14   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-15   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-16   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-17   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-18   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-19   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-20   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-21   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-22   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-23   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-24   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-25   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-26   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-27   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-28   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-29   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-30   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-03-31   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04-01   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04-02   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04-03   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04-04   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04-05   NaN   NaN  NaN   NaN NaN                   NaN              NaN
# 2018-04