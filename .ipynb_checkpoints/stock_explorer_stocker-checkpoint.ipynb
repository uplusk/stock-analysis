# %% [markdown]
# # Stock Analysis Using Stocker

# %% [markdown]
# We start by importing all the necessary libraries.

# %%
# Command for plotting in the notebook
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from stocker import Stocker

# %% [markdown]
# # Creating our Stock Object

# %%
mothersumi= Stocker(ticker = 'MOTHERSUMI', exchange = 'NSE')
# Out:
# MOTHERSUMI Stocker Initialized. Data covers 1998-03-20 to 2018-02-19.

# %% [markdown]
# # Plotting Stock History

# %% [markdown]
# The start and end dates are editable.

# %%
stock_history = mothersumi.stock
stock_history.tail()
# Out:
#            Date    Open   High    Low    Last   Close  Total Trade Quantity  \
# 4784 2018-02-12  363.25  371.9  360.0  361.45  364.45             2097972.0
# 4785 2018-02-14  360.80  361.9  353.5  356.00  357.25             4850146.0
# 4786 2018-02-15  358.00  358.0  340.1  342.00  341.20             5807693.0
# 4787 2018-02-16  343.90  344.0  319.1  327.00  326.75            13368026.0
# 4788 2018-02-19  327.00  333.8  320.6  327.70  327.40             3457333.0
#
#       Turnover (Lacs)         ds  Adj. Close  Adj. Open       y  Daily Change
# 4784          7677.71 2018-02-12      364.45     363.25  364.45          1.20
# 4785         17349.59 2018-02-14      357.25     360.80  357.25         -3.55
# 4786         20054.01 2018-02-15      341.20     358.00  341.20        -16.80
# 4787         43687.26 2018-02-16      326.75     343.90  326.75        -17.15
# 4788         11353.40 2018-02-19      327.40     327.00  327.40          0.40

# %%
mothersumi.plot_stock(start_date = '2015-01-01')
# Out:
# Maximum Adj. Close = 536.45 on 2015-07-20.
# Minimum Adj. Close = 210.80 on 2016-02-25.
# Current Adj. Close = 327.40 on 2018-02-19.

# %% [markdown]
# # Calculate whether you made a profit or a loss

# %% [markdown]
# Here we use 'buy and hold' method from stocker. We specify the number of shares, the start date and the end date, and it calculates profit(if you're lucky enough) or a loss based on the number of shares that you hold.

# %%
mothersumi.buy_and_hold(start_date ='2018-01-22', end_date = '2018-02-09', nshares = 300)
# Out:
# MOTHERSUMI Total buy and hold profit from 2018-01-22 to 2018-02-09 for 300 shares = $-7215.00

# %% [markdown]
# # Creating prophet models

# %%
model, model_data = mothersumi.create_prophet_model()

# %% [markdown]
# Plotiing the weekly and monthly trend components.

# %%
model.plot_components(model_data)
plt.show()

# %% [markdown]
# # Changepoint Date Analysis

# %% [markdown]
# This helps us observe the dates where prices changed significantly.

# %%
mothersumi.changepoint_date_analysis()
# Out:
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 309 2016-05-24      256.45  1.103923
# 285 2016-04-20      268.70  1.068301
# 380 2016-09-02      320.65 -0.770944
# 404 2016-10-10      331.45 -0.768026
# 166 2015-10-21      251.90  0.704038

# %% [markdown]
# The above graph depicts the possible correlation between related google search trends and the changepoints, but I dont think there are any useful inferences here(except the last changepoint, not surprising at all)

# %% [markdown]
# # Predictions

# %% [markdown]
# Now that we have analyzed the stock, the next question is where is it going? For that we will have to turn to predictions!

# %%
model, model_data = mothersumi.create_prophet_model(days = 150)
# Out:
# Predicted Price on 2018-07-19 = INR409.22

# %% [markdown]
# # Now evaluating our predictions

# %% [markdown]
# For our predictions to be meaningful, we must evaluate them on real data.
#
# One way to do this is set aside some historical data as a test set and use data from further back as our training set. In the default evaluation method, we test using the past year and train on the 3 years prior to the test period.
#
# To quantify the accuracy of our predictions, we can find the average rupee error on both the testing and training data, the percentage the actual price was in the predicted confidence interval, and the percentage of times we predicted the correct direction for the stock.

# %%
mothersumi.evaluate_prediction()
# Out:
# C:\Users\133924\Documents\Hitachi Consulting\Financial Analytics\stocker\stocker.py:522: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# Prediction Range: 2017-02-19 to 2018-02-19.
#
# Predicted price on 2018-02-17 = INR401.25.
# Actual price on    2018-02-16 = INR326.75.
#
# Average Absolute Error on Training Data = INR14.96.
# Average Absolute Error on Testing  Data = INR54.52.
#
# When the model predicted an increase, the price increased 51.91% of the time.
# When the model predicted a  decrease, the price decreased  42.61% of the time.
#
# The actual value was within the 80% confidence interval 58.70% of the time.

# %% [markdown]
# The predictions are not very good clearly. We need to tweak some scale parameters to change how much weight the model gives to shift in data.

# %% [markdown]
# # Changepoint Prior Scale Selection

# %% [markdown]
# The changepoint prior scale represents the amount of weight given to the changepoints in the model. This can be used to control overfitting vs underfitting. A higher prior will create a model with more flexibility and more emphasis on the changepoints. This can lead to overfitting because the model will closely follow the training data. Lowering the prior decreases the model flexibility which can cause the opposite problem underfitting. This occurs when our model does not follow the training data closely enough and fails to learn the underlying relationships.

# %% [markdown]
# We can use two methods and choose our scale whatever works best for us, our aim being the prediction being on the right side most of the time

# %% [markdown]
# First, a graphical comparison. We assign some range of priors to get a feel of how they affect the model.

# %%
mothersumi.changepoint_prior_analysis(changepoint_priors=[0.01, 0.05, 0.1, 0.2])

# %% [markdown]
# Next, a quantitative comparison. The changepoint prior validation method is designed to provide numerical backing. We are testing from 2017-02-12 to 2018-02-12, so we need to make sure to use a different validation range. We will select two years prior to the testing date range. The model will be trained on the three years prior to the validation period.

# %%
mothersumi.changepoint_prior_validation(start_date = '2016-02-01', end_date = '2017-03-01', changepoint_priors=[0.01, 0.05, 0.1, 0.2])
# Out:
# Validation Range 2016-02-01 to 2017-03-01.
#
#     cps  train_err  train_range    test_err  test_range
# 0  0.01  29.541120    90.076128  204.096208  120.158861
# 1  0.05  22.222194    73.810035  295.038082  150.923045
# 2  0.10  12.977484    45.690258  194.836353  471.781505
# 3  0.20  11.765448    42.369739  222.849878  613.435784

# %% [markdown]
# Refining the model using different cps, as we can see the error decreases as we increase the priors.

# %%
mothersumi.changepoint_prior_validation(start_date = '2014-02-01', end_date = '2015-05-01', changepoint_priors=[0.01,0.05,0.1,0.3,0.6])
# Out:
# Validation Range 2014-02-03 to 2015-04-30.
#
#     cps  train_err  train_range    test_err  test_range
# 0  0.01  16.444691    51.266469  104.039917   52.792064
# 1  0.05  13.512875    43.614559   96.923311   72.925330
# 2  0.10  12.085318    39.910788  105.732466  127.018660
# 3  0.30   6.168793    21.667241  268.373128  828.374044
# 4  0.60   5.707802    20.429794  233.577821  958.214859

# %% [markdown]
# # Now evaluating the prediction again

# %% [markdown]
# 0.5 seems to be a suitable prior to the model(I tested it several times changing the date range as well as the priors). Hence we set the prior to 0.5 and evaluate.

# %%
mothersumi.changepoint_prior_scale = 0.001

# %%
mothersumi.evaluate_prediction()
# Out:
# C:\Users\133924\Documents\Hitachi Consulting\Financial Analytics\stocker\stocker.py:522: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# Prediction Range: 2017-02-19 to 2018-02-19.
#
# Predicted price on 2018-02-17 = INR342.95.
# Actual price on    2018-02-16 = INR326.75.
#
# Average Absolute Error on Training Data = INR77.42.
# Average Absolute Error on Testing  Data = INR32.53.
#
# When the model predicted an increase, the price increased 56.90% of the time.
# When the model predicted a  decrease, the price decreased  47.69% of the time.
#
# The actual value was within the 80% confidence interval 96.36% of the time.

# %%
mothersumi.weekly_seasonality = True

# %%
mothersumi.evaluate_prediction()
# Out:
# C:\Users\133924\Documents\Hitachi Consulting\Financial Analytics\stocker\stocker.py:522: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# Prediction Range: 2017-02-19 to 2018-02-19.
#
# Predicted price on 2018-02-17 = INR342.95.
# Actual price on    2018-02-16 = INR326.75.
#
# Average Absolute Error on Training Data = INR77.42.
# Average Absolute Error on Testing  Data = INR32.53.
#
# When the model predicted an increase, the price increased 56.90% of the time.
# When the model predicted a  decrease, the price decreased  47.69% of the time.
#
# The actual value was within the 80% confidence interval 96.76% of the time.

# %% [markdown]
# There we set what is best for our model:

# %%
mothersumi.changepoint_prior_scale = 0.001
mothersumi.weekly_seasonality = True

# %% [markdown]
# # Finally it's time to play DA GAME!

# %% [markdown]
# (Copying the rules of the game from stocker.py- Thanks William.)
# Here they are:
#
# We will compare our model with the simple strategy of buying and holding over the same time period. The rules of our game are straightforward:
#
# 1. If we predict the price will increase, we buy stock on that day. If we predict a decrease, we do not play the market.
# 2. If we predicted an increase and the stock does increase, we recieve the change in price of the stock over that day times the number of shares.
# 3. If we predicted an increase and the stock decreases, we lose the change in price of the stock over that day times the number of shares.
#
# We are assuming the "change in price of a share on that day" is the difference between the previous days' closing price and the closing price on our day. For example, if the closing price on Monday was \$14 and the closing price on Tuesday was \$18, we would call that a \$4 change on Tuesday. This is not entirely accurate as stocks prices change a small amount overnight, but it will be acceptable for our game.

# %%
mothersumi.evaluate_prediction(nshares = 300)
# Out:
# C:\Users\133924\Documents\Hitachi Consulting\Financial Analytics\stocker\stocker.py:522: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# C:\Users\133924\Documents\Hitachi Consulting\Financial Analytics\stocker\stocker.py:613: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_pred_increase['pred_profit'] = prediction_profit
# You played the stock market in MOTHERSUMI from 2017-02-19 to 2018-02-19 with 300 shares.
#
# When the model predicted an increase, the price increased 56.90% of the time.
# When the model predicted a  decrease, the price decreased  47.69% of the time.
#
# The total profit using the Prophet model = INR25830.00.
# The Buy and Hold strategy profit =         INR-7290.00.
#
# Thanks for playing the stock market!

# %% [markdown]
# Notice that our profits do not depend on the difference between the final predicted price and the actual price, only on the percentage of the time we correctly predicted the direction.

# %%
mothersumi.evaluate_prediction(start_date = '2014-06-22', end_date = '2015-03-22', nshares=300)
# Out:
# C:\Users\133924\Documents\Hitachi Consulting\Financial Analytics\stocker\stocker.py:522: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# C:\Users\133924\Documents\Hitachi Consulting\Financial Analytics\stocker\stocker.py:613: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_pred_increase['pred_profit'] = prediction_profit
# You played the stock market in MOTHERSUMI from 2014-06-22 to 2015-03-22 with 300 shares.
#
# When the model predicted an increase, the price increased 55.45% of the time.
# When the model predicted a  decrease, the price decreased  53.75% of the time.
#
# The total profit using the Prophet model = INR48240.00.
# The Buy and Hold strategy profit =         INR52500.00.
#
# Thanks for playing the stock market!

# %% [markdown]
# # Time to predict the future (that's what we want right!)

# %% [markdown]
# This function automatically trains on the past 3 years and makes predictions with the uncertainty intervals.

# %%
mothersumi.predict_future(days =150)
# Out:
# Predicted Increase:
#
#           Date    estimate     change       upper       lower
# 3   2018-02-22  304.805141   0.612411  393.889545  212.501791
# 6   2018-02-25  369.007326  64.368596  460.714647  274.002707
# 10  2018-03-01  308.461070   4.546425  399.119891  214.120251
# 11  2018-03-02  313.171175   4.710105  411.778982  224.772896
# 13  2018-03-04  380.719201  67.548025  474.178043  296.560681
# 17  2018-03-08  324.860684   7.353959  417.628045  233.583260
# 18  2018-03-09  329.989874   5.129191  416.151919  234.616360
# 20  2018-03-11  390.485964  60.496090  478.639027  304.573901
# 23  2018-03-14  327.798344   2.336391  421.634547  239.404075
# 24  2018-03-15  336.839575   9.041231  423.802943  247.180372
# 25  2018-03-16  341.529394   4.689819  429.089345  251.892971
# 27  2018-03-18  399.891535  58.362141  486.188690  316.283976
# 30  2018-03-21  337.453043   0.618709  428.935806  246.215398
# 31  2018-03-22  341.396837   3.943794  430.591837  258.174752
# 34  2018-03-25  394.708789  54.870559  492.152727  296.826194
# 36  2018-03-27  337.390740   2.514605  422.194211  245.640596
# 37  2018-03-28  337.765324   0.374583  433.136341  255.109533
# 38  2018-03-29  339.441746   1.676423  430.632912  251.318389
# 41  2018-04-01  396.942547  60.453991  487.240958  311.581344
# 43  2018-04-03  344.272730   3.568878  438.916156  250.243623
# 45  2018-04-05  344.509894   0.927275  432.270838  249.729668
# 48  2018-04-08  408.606011  65.577923  495.592453  310.271850
# 52  2018-04-12  347.473152   0.281120  442.152823  258.703663
# 53  2018-04-13  348.126365   0.653212  434.527439  250.792544
# 55  2018-04-15  417.206375  69.080010  508.482742  322.693284
# 59  2018-04-19  355.249897   1.486107  445.631042  265.946553
# 60  2018-04-20  355.573192   0.323295  452.819710  267.855370
# 62  2018-04-22  414.385139  58.811947  511.514905  324.503944
# 66  2018-04-26  348.573616   4.216367  434.904962  256.503612
# 67  2018-04-27  349.604347   1.030731  446.004915  253.807736
# ..         ...         ...        ...         ...         ...
# 80  2018-05-10  349.155012   4.798442  440.805806  254.621076
# 83  2018-05-13  401.412704  54.392564  485.448712  312.686608
# 85  2018-05-15  349.488961   5.877665  445.213089  266.189665
# 86  2018-05-16  353.569159   4.080198  454.789148  264.666019
# 87  2018-05-17  358.239316   4.670157  446.826160  266.001387
# 90  2018-05-20  415.334445  58.515553  506.683722  329.908062
# 92  2018-05-22  358.013438   1.389736  447.794248  264.349826
# 94  2018-05-24  357.259808   1.010009  444.486637  267.477199
# 97  2018-05-27  419.939570  63.728297  513.608516  330.937638
# 101 2018-05-31  357.078338   1.894867  448.303388  260.832728
# 102 2018-06-01  359.260320   2.181983  448.706296  263.901168
# 104 2018-06-03  426.253956  66.993636  513.416262  328.859448
# 108 2018-06-07  364.576141   4.792898  461.003982  273.229645
# 109 2018-06-08  368.801728   4.225587  463.005531  282.712178
# 111 2018-06-10  431.630979  62.829252  525.926538  340.022257
# 114 2018-06-13  365.200548   0.224236  451.212538  271.221368
# 115 2018-06-14  373.526455   8.325907  460.337539  289.460048
# 116 2018-06-15  379.580409   6.053954  467.684887  287.494468
# 118 2018-06-17  442.127634  62.547225  538.228918  353.832160
# 121 2018-06-20  379.535937   0.689375  468.511340  289.004790
# 122 2018-06-21  384.709780   5.173843  473.566483  292.220946
# 123 2018-06-22  384.751443   0.041663  475.873685  289.881186
# 125 2018-06-24  439.369559  54.618116  534.302775  346.299411
# 127 2018-06-26  379.610404   1.623529  467.217457  285.070258
# 128 2018-06-27  380.189950   0.579546  477.693321  291.257554
# 129 2018-06-28  382.177801   1.987851  473.928164  293.861806
# 132 2018-07-01  431.513771  53.384822  525.056045  345.858591
# 134 2018-07-03  373.682432   1.711365  468.278934  282.829783
# 139 2018-07-08  419.162694  55.019165  510.871368  328.602980
# 146 2018-07-15  400.655326  60.426062  491.372453  311.761819
#
# [67 rows x 5 columns]
#
# Predicted Decrease:
#
#           Date    estimate     change       upper       lower
# 1   2018-02-20  307.846987  -0.942961  403.084895  213.860766
# 2   2018-02-21  304.192729  -3.654258  391.437407  213.972515
# 4   2018-02-23  304.638730  -0.166410  394.274088  216.183740
# 7   2018-02-26  308.507835 -60.499491  392.913318  212.568265
# 8   2018-02-27  306.533769  -1.974066  397.415323  216.752575
# 9   2018-02-28  303.914645  -2.619124  392.479669  218.163109
# 14  2018-03-05  319.222991 -61.496210  413.004103  229.052805
# 15  2018-03-06  317.618406  -1.604585  406.301787  231.443550
# 16  2018-03-07  317.506725  -0.111681  411.844062  226.980907
# 21  2018-03-12  326.461938 -64.024026  413.932794  235.317505
# 22  2018-03-13  325.461953  -0.999985  414.816744  241.048217
# 28  2018-03-19  336.900051 -62.991483  421.403190  244.499954
# 29  2018-03-20  336.834334  -0.065717  429.879029  248.619213
# 32  2018-03-23  339.838231  -1.558607  431.846545  244.607571
# 35  2018-03-26  334.876135 -59.832655  427.809503  248.277713
# 39  2018-03-30  336.488556  -2.953190  431.950985  242.024665
# 42  2018-04-02  340.703851 -56.238696  428.876881  253.160461
# 44  2018-04-04  343.582618  -0.690112  435.866509  259.588068
# 46  2018-04-06  343.028088  -1.481806  439.177533  254.345031
# 49  2018-04-09  351.313974 -57.292037  446.478335  264.857427
# 50  2018-04-10  351.270385  -0.043589  446.130279  261.517914
# 51  2018-04-11  347.192033  -4.078352  441.545828  260.736901
# 56  2018-04-16  358.824057 -58.382318  449.043631  268.286485
# 57  2018-04-17  357.563099  -1.260958  447.750277  267.065218
# 58  2018-04-18  353.763790  -3.799309  440.508926  260.819940
# 63  2018-04-23  350.103227 -64.281912  447.058521  260.557824
# 64  2018-04-24  346.568445  -3.534782  435.204471  252.741209
# 65  2018-04-25  344.357250  -2.211196  435.413669  253.313412
# 70  2018-04-30  338.878614 -64.727613  429.821664  252.242891
# 71  2018-05-01  338.036197  -0.842417  422.926848  241.746338
# ..         ...         ...        ...         ...         ...
# 84  2018-05-14  343.611296 -57.801408  430.202365  247.531594
# 88  2018-05-18  356.818892  -1.420423  448.314784  267.950750
# 91  2018-05-21  356.623703 -58.710743  444.587259  268.726784
# 93  2018-05-23  356.249799  -1.763640  447.366165  262.667658
# 95  2018-05-25  356.211272  -1.048535  454.993932  270.646491
# 98  2018-05-28  360.498316 -59.441253  451.110753  262.857887
# 99  2018-05-29  359.021746  -1.476571  452.492211  267.148790
# 100 2018-05-30  355.183471  -3.838275  440.187150  264.336863
# 105 2018-06-04  365.169713 -61.084243  454.397543  270.265594
# 106 2018-06-05  362.478898  -2.690815  458.713400  272.393206
# 107 2018-06-06  359.783243  -2.695655  447.313427  272.925660
# 112 2018-06-11  367.660181 -63.970798  460.411500  275.423328
# 113 2018-06-12  364.976312  -2.683870  454.790450  269.501718
# 119 2018-06-18  379.417467 -62.710166  472.440634  286.551810
# 120 2018-06-19  378.846562  -0.570905  466.117453  286.162031
# 126 2018-06-25  377.986875 -61.382684  469.622112  287.986114
# 130 2018-06-29  378.128949  -4.048852  466.742217  286.239166
# 133 2018-07-02  371.971066 -59.542705  462.629980  286.744089
# 135 2018-07-04  371.671973  -2.010459  463.423135  283.647075
# 136 2018-07-05  370.115882  -1.556091  461.997137  280.568073
# 137 2018-07-06  364.143529  -5.972352  454.632710  275.150613
# 140 2018-07-09  358.705943 -60.456752  445.059006  268.424459
# 141 2018-07-10  356.598897  -2.107046  445.908437  267.800987
# 142 2018-07-11  349.782593  -6.816304  441.170537  254.738161
# 143 2018-07-12  345.467186  -4.315407  442.211104  252.056894
# 144 2018-07-13  340.229265  -5.237922  434.840003  250.900633
# 147 2018-07-16  340.847194 -59.808133  427.000474  246.026486
# 148 2018-07-17  338.539086  -2.308108  430.029371  248.733980
# 149 2018-07-18  332.691182  -5.847904  415.676095  241.255467
# 150 2018-07-19  331.136169  -1.555013  425.819047  240.413576
#
# [62 rows x 5 columns]
